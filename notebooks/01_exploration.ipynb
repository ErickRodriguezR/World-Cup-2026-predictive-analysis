# %%
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()

df_matches = pd.read_csv("../data/raw/WorldCupMatches.csv")
df_cups = pd.read_csv("../data/raw/WorldCups.csv")

# %%
print("Matches:", df_matches.describe())
print("Cups:", df_cups.describe())

# df_matches.head()
# df_cups.head()

API_KEY = os.getenv("FOOTBALL_API_KEY")
# Out:
# Matches:               Year  Home Team Goals  Away Team Goals     Attendance  \
# count   852.000000       852.000000       852.000000     850.000000
# mean   1985.089202         1.811033         1.022300   45164.800000
# std      22.448825         1.610255         1.087573   23485.249247
# min    1930.000000         0.000000         0.000000    2000.000000
# 25%    1970.000000         1.000000         0.000000   30000.000000
# 50%    1990.000000         2.000000         1.000000   41579.500000
# 75%    2002.000000         3.000000         2.000000   61374.500000
# max    2014.000000        10.000000         7.000000  173850.000000
#
#        Half-time Home Goals  Half-time Away Goals       RoundID       MatchID
# count            852.000000            852.000000  8.520000e+02  8.520000e+02
# mean               0.708920              0.428404  1.066177e+07  6.134687e+07
# std                0.937414              0.691252  2.729613e+07  1.110572e+08
# ...

# %%
total_matches = df_matches.shape[0] #all the matches in all World Cup
missing_values = df_matches.isnull().sum() #empty values in the dataset
year_range = df_matches["Year"].max() - df_matches["Year"].min() #range of 1930 to 2014

home_teams = df_matches["Home Team Name"]
away_teams = df_matches["Away Team Name"]
unique_teams = pd.concat([home_teams, away_teams]).nunique() #sum of all the unique teams

df_matches["total_goals"] = df_matches["Home Team Goals"] + df_matches["Away Team Goals"]
average_goals = df_matches["total_goals"].mean() #average goals per match
# Out:
# 2.83
