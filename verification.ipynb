# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import duckdb
import requests

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("duckdb:", duckdb.__version__)
print("All ready for the World Cup 2026")
# Out:
# pandas: 2.2.2
# numpy: 1.26.4
# scikit-learn: 1.5.0
# duckdb: 0.10.3
# Todo listo para el proyecto Mundial 2026
